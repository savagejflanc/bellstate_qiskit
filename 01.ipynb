# %% [markdown]
# Tor creat a maximlly entangled Bell States we need to
# 1. import QuantumCircuit to create a quantum circuit for two qubits that are registerd from QuantumRegister
# 2. apply Hadamard Gate to the qubit 0
#         i. A Hadamard gate creates a superposition for qubit-0 into both 0 and 1
# 3. applying a C-not gate where the control is q0 and target is q1
# 4. We measure the qubit to find the answer/probability which is distributted equally after the combination of Hadamard and C-NOT
# 5. Creating the figure that shows the circuit diagram

# %%
from qiskit import QuantumCircuit, QuantumRegister  #importing the model to create a circuit for 2 qubits 
qubits=QuantumRegister(2,name="q" )  #we name those qubits as q1, q2.
q0,q1=qubits  
circuit=QuantumCircuit(qubits)
circuit.h(0)  # We apply Hadamard gate in the second qubit
circuit.cx(q0,q1)
circuit.measure_all()
circuit.draw("mpl")

# %%
#A Qiskit class used to estimate probabilities of measurement outcomes by sampling from a quantum circuit.
#plot_histogram: Visualizes the measurement results as a histogram (shows probabilities for each possible outcome like "00", "11", etc.).

# %%
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

sampler = Sampler()
results = sampler.run(circuit).result()
statistics = results.quasi_dists[0].binary_probabilities()
display(plot_histogram(statistics))
circuit.draw(output="mpl")
# Out:
# C:\Users\chhet\AppData\Local\Temp\ipykernel_20064\2436510287.py:4: DeprecationWarning: The class ``qiskit.primitives.sampler.Sampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Sampler` class is `StatevectorSampler`.
#   sampler = Sampler()

# %%
# test``
